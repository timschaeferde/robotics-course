# %%
import sys
sys.path.append('../../build')
import cv2 as cv
import numpy as np

import libry as ry
import time
print(cv.__version__)
# Out:
# 4.5.3

# %%
#Let's edit the real world before we create the simulation
RealWorld = ry.Config()
RealWorld.addFile("../../scenarios/ex05_redball.g")
D = RealWorld.view()

ball = RealWorld.getFrame("ball")
ball.setContact(1)

# %%
#RealWorld.addFrame(camera_fixpoint)

# %%
# instantiate the simulation
S = RealWorld.simulation(ry.SimulatorEngine.bullet, verbose=1)
S.addSensor("camera")

# %%
# we're adding an "imp" to the simulation, which is a little process that can inject perturbations
S.addImp(ry.ImpType.objectImpulses, ['ball'], [])

# %%
# create your model world
C = ry.Config()
C.addFile('../../scenarios/pandasTable.g')
cameraFrame = C.frame("camera")
D2 = C.view()

#the focal length
f = 0.895
f = f * 360.
fxfypxpy = [f, f, 320., 180.]

# %%
config_obj_name = "conf_ball"

# delete if necceary
#C.delFrame(config_obj_name)

obj = C.addFrame(config_obj_name,"camera")

obj.setShape(ry.ST.sphere, [.03])
obj.setPosition([0., .1, 1.6])
obj.setColor([1.,0,0])


objectPosition = RealWorld.getFrame("ball").getPosition()

#set the model object to percept
obj.setPosition(objectPosition)

# %% [markdown]
# # Setup complete here!

# %% [markdown]
# ## OpenCV find red ball code:

# %%
def _segment_redball(rgb):
    rgb = cv.cvtColor(rgb, cv.COLOR_BGR2RGB)
    hsv = cv.cvtColor(rgb, cv.COLOR_BGR2HSV)

    mask1 = cv.inRange(hsv, (0, 120, 70), (10, 255, 255))
    mask2 = cv.inRange(hsv, (170, 120, 70), (180, 255, 255))

    # if len(mask1)>0: cv.imshow('OPENCV - mask1',  mask1)
    # if len(mask2)>0: cv.imshow('OPENCV - mask2',  mask2)
    mask = mask1 + mask2

    # create empty mask
    filtered_mask = np.zeros(mask.shape, np.uint8)

    # if len(filtered_mask)>0: cv.imshow('OPENCV - filtered_mask',  filtered_mask)
    # find contours
    contours, _ = cv.findContours(mask, cv.RETR_LIST, cv.CHAIN_APPROX_SIMPLE)

    if len(contours) > 0:
        # find largest contour
        largest, idx = 0, None
        for i, c in enumerate(contours):
            # remove noise
            if c.shape[0] < 10: continue
            if cv.contourArea(c) > largest:
                largest = cv.contourArea(c)
                idx = i
        if i is not None: 
            idx=0
        cv.drawContours(filtered_mask, contours[idx], -1, (255, 255, 255), -1)
    return filtered_mask


def _image_pointcloud(depth, mask):
    # if len(mask) > 0: cv.imshow('OPENCV - mask1', mask * 255)
    # cv.waitKey(100)
    mask_pixels = np.where(mask > 0)
    pointcloud = np.empty((mask_pixels[0].shape[0], 3))
    pointcloud[:, 0] = mask_pixels[1]  # x pixels
    pointcloud[:, 1] = mask_pixels[0]  # y pixels
    pointcloud[:, 2] = depth[mask_pixels[0], mask_pixels[1]]
    return pointcloud


def _meter_pointcloud(pixel_points, fxfypxpy):
    points = np.empty(np.shape(pixel_points))
    for i, p in enumerate(pixel_points):
        x = p[0]
        y = p[1]
        d = p[2]

        px = fxfypxpy[-2]
        py = fxfypxpy[-1]

        x_ = d * (x - px) / fxfypxpy[0]
        y_ = -d * (y - py) / fxfypxpy[1]
        z_ = -d
        points[i] = [x_, y_, z_]
    return points


def find_ball(rgb, depth, fxfypxpy):
    mask = _segment_redball(rgb)
    pixel_points = _image_pointcloud(depth, mask)
    obj_points = _meter_pointcloud(pixel_points, fxfypxpy)
    return obj_points, mask

# %% [markdown]
# # Lift and drop ball code:

# %%
def liftAndDrop(C, gripper, lift_time = 0.7, steps = 10):
    # calculate a lift of the ball
    
    # we want to optimize a single step (1 phase, 1 step/phase, duration=1, k_order=1)
    komo = C.komo_path(lift_time,steps, 3., True)
    komo.addObjective(  [lift_time], 
                        ry.FS.position, 
                        [gripper], 
                        ry.OT.sos, 
                        [1e2],
                        [.2,.2,1.2])
    komo.addObjective(  [lift_time], 
                        ry.FS.qItself, 
                        [], 
                        ry.OT.eq, 
                        [1e2], 
                        order=1)
    komo.addObjective(  [lift_time], 
                        ry.FS.vectorY, 
                        [gripper], 
                        ry.OT.sos, 
                        [1e2],
                        [0.,0.,1]);
    komo.addObjective(  [lift_time], 
                        ry.FS.vectorX, 
                        [gripper], 
                        ry.OT.sos, 
                        [1e2],
                        [0.,1.,0.]);
    komo.optimize()

    # here loop for upwards move
    for frame,tau in zip(komo.getPathFrames(),komo.getPathTau()):
        time.sleep(tau)
        [rgb, depth] = S.getImageAndDepth()  #we don't need images with 100Hz, rendering is slow

        C.setFrameState(frame)

        q= C.getJointState()

        #send position to the simulation
        S.step(q, tau, ry.ControlMode.position)

    tau = 0.01
    for t in range(100):
        time.sleep(tau)
        
        if t%20 == 0:
            [rgb, depth] = S.getImageAndDepth()  #we don't need images with 100Hz, rendering is slow

        if S.getGripperWidth(gripper) < 0.04:
            S.openGripper(gripper,speed=2.)

        if(S.getGripperWidth(gripper)>0.04 and not S.getGripperIsGrasping(gripper)):
            print("DOPPED!")
            break
        

        S.step([], tau, ry.ControlMode.none)

# %%
def pickBall(C,gripper):
    points = []
    tau = .01

    gripping = False
    grasped = False
    
    objectPosition = [0., 0., 0.]

    for t in range(400):
        time.sleep(0.01)
        #grab sensor readings from the simulation
        q = S.get_q()
        if t%10 == 0:
            [rgb, depth] = S.getImageAndDepth()  #we don't need images with 100Hz, rendering is slow
            points = S.depthData2pointCloud(depth, fxfypxpy)
            cameraFrame.setPointCloud(points, rgb)

            pos_bkp = objectPosition
            # get points of ball with opencv
            obj_points, mask = find_ball(rgb,depth,fxfypxpy)

            # get position of ball with mean of points
            objectPosition = obj_points.mean(axis=0)

            if np.isnan(objectPosition).any():
                objectPosition = pos_bkp

            #set the model object to percept (relative to camera because the position from the pointcloud is in camera coord.)
            obj.setRelativePosition(objectPosition)

        C.setJointState(q) #set your robot model to match the real q

        y,_ = C.evalFeature(ry.FS.positionDiff, [gripper, config_obj_name])
        distance = np.linalg.norm(y)
        # start grapsing here
    
        if t > 40 and not gripping:
            # we want to optimize a single step (1 phase, 1 step/phase, duration=1, k_order=1)
            komo = C.komo_path(1.,10, 3., True)
            komo.add_qControlObjective([], 1, 1.)
            komo.addObjective([1.], 
                              ry.FS.positionDiff, 
                              [gripper, config_obj_name], 
                              ry.OT.eq, 
                              [1e2],
                              [0.,-0.,0.]);
            komo.addObjective([1.], 
                              ry.FS.distance, 
                              [gripper, config_obj_name], 
                              ry.OT.sos, 
                               [1e2],
                              [-.06]);
            komo.addObjective([1.], 
                              ry.FS.vectorZ, 
                              [gripper], 
                              ry.OT.sos, 
                              [1e2],
                              [1.7,0.,1]);
            komo.addObjective([1.], 
                              ry.FS.vectorX, 
                              [gripper], 
                              ry.OT.sos, 
                              [1e2],
                              [0.,1.,0.]);

            # optimize
            komo.optimize()
            
            if distance <.2:
                C.setFrameState(komo.getFrameState(max(9,int(9-distance*5*7))))
            else:
                C.setFrameState(komo.getFrameState(2))
            # get joint states
            q = C.getJointState()


        
        if not gripping and (distance < .02):
            S.closeGripper(gripper, speed = 2.)
            gripping = True
        
        
        if gripping and (S.getGripperWidth(gripper) < .01):
            gripping=False
            S.openGripper(gripper, speed = 2.)

        if gripping  and S.getGripperIsGrasping(gripper):
            print("GRASPED!")
            grasped = True
            break

        #send no controls to the simulation
        S.step(q, tau, ry.ControlMode.position)

# %% [markdown]
# # Simulation start here

# %%
tau = .01



for t in range(70):
    time.sleep(0.01)
    if t%10 == 0:
        [rgb, depth] = S.getImageAndDepth()  #we don't need images with 100Hz, rendering is slow
        points = S.depthData2pointCloud(depth, fxfypxpy)
        cameraFrame.setPointCloud(points, rgb)
    S.step([], tau, ry.ControlMode.none)

# %%
pickBall(C,"R_gripper")
# Out:
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.113386 (kin:0.00195 coll:0.081625 feat:0.017224 newton: 0.004654) setJointStateCount:34
#    sos:9536.56 ineq:0 eq:0.080755
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.088755 (kin:0.001504 coll:0.058074 feat:0.013456 newton: 0.009165) setJointStateCount:28
#    sos:9535.79 ineq:0 eq:0.0736012
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.074299 (kin:0.001896 coll:0.052949 feat:0.010637 newton: 0.00318) setJointStateCount:25
#    sos:9535.26 ineq:0 eq:0.0696469
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.081269 (kin:0.002358 coll:0.054062 feat:0.013333 newton: 0.003139) setJointStateCount:24
#    sos:9535.23 ineq:0 eq:0.0351495
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.072431 (kin:0.001238 coll:0.054399 feat:0.008858 newton: 0.002853) setJointStateCount:23
#    sos:9535.04 ineq:0 eq:0.0287471
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.062119 (kin:0.001065 coll:0.040602 feat:0.007632 newton: 0.00662) setJointStateCount:20
#    sos:9534.89 ineq:0 eq:0.0272063
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.074998 (kin:0.003656 coll:0.052273 feat:0.010258 newton: 0.003378) setJointStateCount:25
#    sos:9535.44 ineq:0 eq:0.0155045
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.048432 (kin:0.000797 coll:0.032641 feat:0.00464 newton: 0.004296) setJointStateCount:10
#    sos:9534.67 ineq:0 eq:0.0406293
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# GRASPED!
# ** optimization time:0.113954 (kin:0.001926 coll:0.078513 feat:0.021336 newton: 0.004729) setJointStateCount:35
#    sos:9535.17 ineq:0 eq:0.01549

# %%
liftAndDrop(C,"R_gripper")
# Out:
# ** KOMO::run solver:sparse collisions:1 x-dim:98 T:7 k:2 phases:0.7 stepsPerPhase:10 tau:0.3  #timeSlices:9 #totalDOFs:98 #frames:882
# ** optimization time:0.021257 (kin:0.000442 coll:0.015533 feat:0.002172 newton: 0.001032) setJointStateCount:10
#    sos:1.86125 ineq:0 eq:8.12612e-06
# DOPPED!

# %%
for round in range (5):
    tau = .01

    for t in range(100):
        time.sleep(0.01)
        if t%10 == 0:
            [rgb, depth] = S.getImageAndDepth()  #we don't need images with 100Hz, rendering is slow
            points = S.depthData2pointCloud(depth, fxfypxpy)
            cameraFrame.setPointCloud(points, rgb)
        S.step([], tau, ry.ControlMode.none)
    
    pickBall(C,"R_gripper")
    
    liftAndDrop(C,"R_gripper")
# Out:
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.066361 (kin:0.001093 coll:0.050771 feat:0.007206 newton: 0.002649) setJointStateCount:24
#    sos:9535.8 ineq:0 eq:0.0187545
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.064723 (kin:0.001122 coll:0.048409 feat:0.007766 newton: 0.002723) setJointStateCount:24
#    sos:9535.9 ineq:0 eq:0.0141649
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.071393 (kin:0.001274 coll:0.045255 feat:0.014318 newton: 0.005123) setJointStateCount:27
#    sos:9535.16 ineq:0 eq:0.0180694
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.057465 (kin:0.001057 coll:0.040389 feat:0.006251 newton: 0.003041) setJointStateCount:21
#    sos:9534.15 ineq:0 eq:0.0935171
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.065405 (kin:0.001157 coll:0.048781 feat:0.007165 newton: 0.002727) setJointStateCount:25
#    sos:9534.89 ineq:0 eq:0.0172367
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.115125 (kin:0.002138 coll:0.080485 feat:0.018147 newton: 0.00568) setJointStateCount:38
#    sos:9535.39 ineq:0 eq:0.0163968
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.044199 (kin:0.000803 coll:0.031979 feat:0.005168 newton: 0.001722) setJointStateCount:14
#    sos:9534.8 ineq:0 eq:0.0113695
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.042753 (kin:0.000713 coll:0.032494 feat:0.004459 newton: -1216.02) setJointStateCount:14
#    sos:9534.66 ineq:0 eq:0.0129871
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.053594 (kin:0.000868 coll:0.037857 feat:0.007212 newton: 0.002195) setJointStateCount:17
#    sos:9534.85 ineq:0 eq:0.0296922
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.04971 (kin:0.001044 coll:0.033196 feat:0.006159 newton: 0.002149) setJointStateCount:17
#    sos:9534.74 ineq:0 eq:0.0710897
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.106098 (kin:0.001986 coll:0.072452 feat:0.012235 newton: 0.005493) setJointStateCount:36
#    sos:9535.92 ineq:0 eq:0.0273283
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.049347 (kin:0.00101 coll:0.035627 feat:0.005664 newton: 0.002093) setJointStateCount:17
#    sos:9534.43 ineq:0 eq:0.0431211
# **ry-c++-log** /home/tim/git/robotics-course_tim/rai/rai/Kin/kin_bullet.cpp:changeObjectType:154(-1) frame ball (R_gripper) 	{  Q:[-0.00401243, 0.00260671, 0.00394196, -0.455704, -0.390352, -0.523546, 0.604863], joint:rigid, shape:sphere, size:[0.03], color:[1, 0, 0], contact:1, mass:0.2 }
#  is already of type kinematic
#
# ** WARNING:/home/tim/git/robotics-course_tim/rai/rai/Kin/kin_bullet.cpp:changeObjectType:154(-1) frame ball (R_gripper) 	{  Q:[-0.00401243, 0.00260671, 0.00394196, -0.455704, -0.390352, -0.523546, 0.604863], joint:rigid, shape:sphere, size:[0.03], color:[1, 0, 0], contact:1, mass:0.2 }
#  is already of type kinematic
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# GRASPED!
# ** optimization time:0.031111 (kin:0.000552 coll:0.023424 feat:0.00303 newton: 0.001602) setJointStateCount:8
#    sos:9534.05 ineq:0 eq:0.0865052
# ** KOMO::run solver:sparse collisions:1 x-dim:98 T:7 k:2 phases:0.7 stepsPerPhase:10 tau:0.3  #timeSlices:9 #totalDOFs:98 #frames:882
# ** optimization time:0.01217 (kin:0.000242 coll:0.00891 feat:0.001174 newton: 0.000572) setJointStateCount:8
#    sos:0.718864 ineq:0 eq:5.37898e-06
# DOPPED!
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.070473 (kin:0.001223 coll:0.04674 feat:0.008788 newton: 0.002597) setJointStateCount:18
#    sos:9535.52 ineq:0 eq:0.00927421
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.073421 (kin:0.001191 coll:0.051169 feat:0.010206 newton: 0.003563) setJointStateCount:21
#    sos:9534.69 ineq:0 eq:0.0454213
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.067404 (kin:0.001071 coll:0.047862 feat:0.010904 newton: 0.002262) setJointStateCount:20
#    sos:9534.8 ineq:0 eq:0.0234418
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.064672 (kin:0.001135 coll:0.043705 feat:0.008173 newton: 0.00244) setJointStateCount:20
#    sos:9534.58 ineq:0 eq:0.0349878
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.057343 (kin:0.000916 coll:0.037965 feat:0.00605 newton: 0.003694) setJointStateCount:16
#    sos:9534.88 ineq:0 eq:0.00499156
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.053846 (kin:0.000976 coll:0.037156 feat:0.005199 newton: 0.001858) setJointStateCount:14
#    sos:9534.79 ineq:0 eq:0.0107973
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.052304 (kin:0.00097 coll:0.036181 feat:0.006414 newton: 0.002735) setJointStateCount:13
#    sos:9534.21 ineq:0 eq:0.0776608
# GRASPED!
# ** KOMO::run solver:sparse collisions:1 x-dim:98 T:7 k:2 phases:0.7 stepsPerPhase:10 tau:0.3  #timeSlices:9 #totalDOFs:98 #frames:882
# ** optimization time:0.02543 (kin:0.004398 coll:0.017077 feat:0.00165 newton: 0.000813) setJointStateCount:9
#    sos:1.65894 ineq:0 eq:4.79455e-06
# DOPPED!
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.053676 (kin:0.000921 coll:0.039836 feat:0.006902 newton: 0.002141) setJointStateCount:18
#    sos:9535.62 ineq:0 eq:0.00638856
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.068166 (kin:0.001151 coll:0.050856 feat:0.007655 newton: 0.002862) setJointStateCount:24
#    sos:9535.15 ineq:0 eq:0.0207178
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.078573 (kin:0.001305 coll:0.05654 feat:0.008381 newton: 0.003248) setJointStateCount:27
#    sos:9534.99 ineq:0 eq:0.0189191
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.082408 (kin:0.001323 coll:0.058049 feat:0.014726 newton: 0.003037) setJointStateCount:25
#    sos:9534.88 ineq:0 eq:0.0171845
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.051056 (kin:0.001603 coll:0.038234 feat:0.005566 newton: -1225.58) setJointStateCount:16
#    sos:9534.87 ineq:0 eq:0.0114954
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.056766 (kin:0.000986 coll:0.042418 feat:0.006153 newton: 0.003058) setJointStateCount:21
#    sos:9534.05 ineq:0 eq:0.073433
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.050256 (kin:0.001009 coll:0.03647 feat:0.006458 newton: 0.002013) setJointStateCount:18
#    sos:9534.09 ineq:0 eq:0.0668779
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.062993 (kin:0.00321 coll:0.041525 feat:0.007217 newton: 0.00336) setJointStateCount:24
#    sos:9534.79 ineq:0 eq:0.0866387
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.05601 (kin:0.00098 coll:0.035992 feat:0.010239 newton: 0.002244) setJointStateCount:20
#    sos:9534.59 ineq:0 eq:0.018147
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.038105 (kin:0.000729 coll:0.026575 feat:0.004215 newton: 0.001601) setJointStateCount:15
#    sos:9534.84 ineq:0 eq:0.0022207
# GRASPED!
# ** KOMO::run solver:sparse collisions:1 x-dim:98 T:7 k:2 phases:0.7 stepsPerPhase:10 tau:0.3  #timeSlices:9 #totalDOFs:98 #frames:882
# ** optimization time:0.025536 (kin:0.000382 coll:0.018114 feat:0.00182 newton: 0.000919) setJointStateCount:11
#    sos:2.82717 ineq:0 eq:4.7059e-06
# GRASPED!
# ** KOMO::run solver:sparse collisions:1 x-dim:98 T:7 k:2 phases:0.7 stepsPerPhase:10 tau:0.3  #timeSlices:9 #totalDOFs:98 #frames:882
# ** optimization time:0.010669 (kin:0.000139 coll:0.005402 feat:0.003819 newton: 0.000252) setJointStateCount:4
#    sos:3.40258e-05 ineq:0 eq:2.32487e-06
# **ry-c++-log** /home/tim/git/robotics-course_tim/rai/rai/Kin/kin_bullet.cpp:changeObjectType:154(-1) frame ball (R_gripper) 	{  Q:[-0.000646789, -0.007866, -0.00138729, -0.588603, 0.490644, -0.378637, 0.519085], joint:rigid, shape:sphere, size:[0.03], color:[1, 0, 0], contact:1, mass:0.2 }
#  is already of type kinematic
#
# ** WARNING:/home/tim/git/robotics-course_tim/rai/rai/Kin/kin_bullet.cpp:changeObjectType:154(-1) frame ball (R_gripper) 	{  Q:[-0.000646789, -0.007866, -0.00138729, -0.588603, 0.490644, -0.378637, 0.519085], joint:rigid, shape:sphere, size:[0.03], color:[1, 0, 0], contact:1, mass:0.2 }
#  is already of type kinematic
# DOPPED!
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.102302 (kin:0.005822 coll:0.071829 feat:0.011205 newton: 0.00598) setJointStateCount:30
#    sos:9535.71 ineq:0 eq:0.00982667
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.075249 (kin:0.001906 coll:0.04752 feat:0.014572 newton: 0.003068) setJointStateCount:21
#    sos:9534.71 ineq:0 eq:0.0381242
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.073981 (kin:0.001251 coll:0.050126 feat:0.010417 newton: 0.00684) setJointStateCount:20
#    sos:9534.9 ineq:0 eq:0.0139209
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.069836 (kin:0.001274 coll:0.046484 feat:0.00825 newton: 0.003953) setJointStateCount:20
#    sos:9534.84 ineq:0 eq:0.0119677
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.031088 (kin:0.000654 coll:0.020777 feat:0.003349 newton: 0.001227) setJointStateCount:12
#    sos:9533.9 ineq:0 eq:0.0762623
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.04859 (kin:0.000835 coll:0.031023 feat:0.010296 newton: 0.002289) setJointStateCount:14
#    sos:9534.78 ineq:0 eq:0.0113172
# ** KOMO::run solver:sparse collisions:1 x-dim:140 T:10 k:2 phases:1 stepsPerPhase:10 tau:0.3  #timeSlices:12 #totalDOFs:140 #frames:1176
# ** optimization time:0.036969 (kin:0.000744 coll:0.025424 feat:0.004823 newton: -1233.25) setJointStateCount:12
#    sos:9533.7 ineq:0 eq:0.0929023
# GRASPED!
# ** KOMO::run solver:sparse collisions:1 x-dim:98 T:7 k:2 phases:0.7 stepsPerPhase:10 tau:0.3  #timeSlices:9 #totalDOFs:98 #frames:882
# ** optimization time:0.026004 (kin:0.00052 coll:0.016453 feat:0.002282 newton: 0.001286) setJointStateCount:9
#    sos:1.52914 ineq:0 eq:1.79202e-06
# DOPPED!

# %%
cv.destroyAllWindows()
